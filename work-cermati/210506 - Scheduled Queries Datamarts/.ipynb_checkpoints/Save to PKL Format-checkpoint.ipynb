# %%
# %reload_ext google.cloud.bigquery
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="C:\\Users\\Cermati\\AppData\\Roaming\\gcloud\\application_default_credentials.json"
print(os.environ["GOOGLE_APPLICATION_CREDENTIALS"])
# Out:
# C:\Users\Cermati\AppData\Roaming\gcloud\application_default_credentials.json

# %%
# %%bigquery param1 --project athena-179008
# SELECT * FROM vayu_external.scheduled_query_athena179008

# %%
# param1['updateTime'] = param1['updateTime'].astype(str).str[0:10]
# param1['startTime'] = param1['startTime'].astype(str).str[0:10]
# param1['nextRunTime'] = param1['nextRunTime'].astype(str).str[0:10]
param1.head()
# Out:
#                                                 name destinationDatasetId  \
# 0  projects/735081149669/locations/asia-southeast...
# 1  projects/735081149669/locations/asia-southeast...
# 2  projects/735081149669/locations/asia-southeast...             vayu_dev
# 3  projects/735081149669/locations/asia-southeast...             vayu_dev
# 4  projects/735081149669/locations/asia-southeast...
#
#                                          displayName  \
# 0                     Indodana Facebook Ads Transfer
# 1                                 sammith test query
# 2                             test_query_for_sammith
# 3  marketing_indodana_ops_field_collections_datam...
# 4  marketing_indodana_telesales_performance_sheet...
#
#                         updateTime     dataSourceId  \
# 0 2020-08-25 04:55:07.076937+00:00  scheduled_query
# 1 2020-12-15 04:43:44.527948+00:00  scheduled_query
# 2 2020-12-15 04:43:40.443463+00:00  scheduled_query
# ...

# %%
param1.to_pickle("original/data.pkl")
